# %% [markdown]
# # Lab2 — Building and Training a CNN on CIFAR-10
#
# **Course**: Deep Learning for Image Analysis
#
# **Class**: M2 IASD App
#
# **Professor**: Mehyar MLAWEH
#
# **Deadline:** 🗓️ **Saturday, March 14th (23:59)**
#
#
# **Goal:** implement (piece by piece) a Convolutional Neural Network (CNN) and train it for image classification.
#
# You will learn how to:
# - Load and explore an image dataset with `torchvision`
# - Build CNN blocks (`Conv2d`, `BatchNorm2d`, `ReLU`, `MaxPool2d`)
# - Move data and models to **GPU** in Google Colab
# - Train a model (loss, optimizer, backprop, evaluation)
#
# ⚠️ This notebook is **intentionally incomplete**.
# Whenever you see **`# TODO`**, you are expected to write code.
#
# ---
#
# ## Dataset: CIFAR-10
#
# CIFAR-10 is a classic dataset of **60,000 color images** of size **32×32** in **10 classes**.
# - 50,000 training images
# - 10,000 test images
# - 10 classes: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck
#
# Official page (read the description): https://www.cs.toronto.edu/~kriz/cifar.html

# %% [markdown]
# ## 0) Colab + GPU Setup
#
# In Colab:
# - **Runtime → Change runtime type → Hardware accelerator → GPU**
#
# Then run the cell below to verify CUDA is available.

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
    print("Device count:", torch.cuda.device_count())
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# GPU name: Tesla T4
# Device count: 1

# %% [markdown]
# ### Device selection (CPU or GPU)
#
# We will use `cuda` if available, otherwise `cpu`.

# %%
# TODO: set the device to CUDA if available, else CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ## 1) Imports
#
# If you're in Colab, `torchvision` is typically already installed.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

import torchvision
from torchvision import transforms

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 2) Load CIFAR-10
# CIFAR-10 is directly available in torchvision, so we don’t need to download it manually.
#
# Official PyTorch documentation:
# https://docs.pytorch.org/vision/main/generated/torchvision.datasets.CIFAR10.html
#
# We’ll use `torchvision.datasets.CIFAR10`.
#
# We also apply a transformation pipeline:
# - Convert images to tensors
# - Normalize images
#
# Normalization helps training stability (inputs typically centered / scaled).

# %%
# Normalization values commonly used for CIFAR-10
# https://github.com/kuangliu/pytorch-cifar/issues/19

CIFAR10_MEAN = (0.4914, 0.4822, 0.4465)
CIFAR10_STD  = (0.2470, 0.2435, 0.2616)

train_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(CIFAR10_MEAN, CIFAR10_STD),
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(CIFAR10_MEAN, CIFAR10_STD),
])

train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=train_transform,
)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=True,
    transform=test_transform,
)

classes = train_dataset.classes
print("Classes:", classes)
print("Train size:", len(train_dataset))
print("Test size:", len(test_dataset))
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 49.1MB/s]
# Classes: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Train size: 50000
# Test size: 10000

# %% [markdown]
# ## 3) Visualize the dataset
#
# We’ll draw a small grid of images **before** we start building the CNN.
#
# ⚠️ Our dataset images are normalized, so we need to *unnormalize* them for display.

# %%
def unnormalize(img_tensor, mean=CIFAR10_MEAN, std=CIFAR10_STD):
    """Undo normalization for visualization."""
    mean = torch.tensor(mean).view(3, 1, 1)
    std = torch.tensor(std).view(3, 1, 1)
    return img_tensor * std + mean

def show_grid(dataset, classes, n=16, seed=0):
    rng = np.random.default_rng(seed)
    idxs = rng.choice(len(dataset), size=n, replace=False)

    fig, axes = plt.subplots(int(np.sqrt(n)), int(np.sqrt(n)), figsize=(8, 8))
    axes = axes.flatten()

    for ax, idx in zip(axes, idxs):
        x, y = dataset[idx]
        x_vis = unnormalize(x).clamp(0, 1)
        ax.imshow(x_vis.permute(1, 2, 0))
        ax.set_title(classes[y], fontsize=9)
        ax.axis("off")

    plt.tight_layout()
    plt.show()

show_grid(train_dataset, classes, n=16, seed=42)

# %% [markdown]
# ## 4) DataLoaders
#
# We will batch data and shuffle the training set.
#
# **Tip:** using a larger batch size can improve GPU utilization.

# %%
# TODO: choose batch size (common values: 64, 128)
batch_size = 128

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_dataset,  batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=True)

# Quick sanity check
x, y = next(iter(train_loader))
print("Batch images:", x.shape)  # expected: [B, 3, 32, 32]
print("Batch labels:", y.shape)  # expected: [B]
# Out:
# Batch images: torch.Size([128, 3, 32, 32])
# Batch labels: torch.Size([128])

# %% [markdown]
# ## 5) Build the CNN step by step
#
# We’ll build the network in **parts**:
#
# ### Part A — a Conv Block
# A common modern pattern is:
#
# **Conv → BatchNorm → ReLU → (optional Pool)**
#
# This block will be reused.

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, padding=1, use_pool=True, stride=1):
        super().__init__()

        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size,
                              padding=padding, stride=stride)  
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.pool = nn.MaxPool2d(2) if use_pool else nn.Identity()

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.pool(x)
        return x

# %% [markdown]
# ### Part B — the Classifier Head
#
# After convolution blocks, we typically **flatten** and use linear layers.
#
# We will use:
# - `Flatten`
# - `Linear`
# - `ReLU`
# - `Dropout` (helps regularization)

# %%
class ClassifierHead(nn.Module):
    def __init__(self, in_features, num_classes=10, hidden=128, dropout=0.2):
        super().__init__()
        self.flatten = nn.Flatten()

        # TODO: define first linear layer (in_features -> hidden)
        self.fc1 = nn.Linear(in_features, hidden)

        self.relu = nn.ReLU(inplace=True)
        self.drop = nn.Dropout(dropout)

        # TODO: define output linear layer (hidden -> num_classes)
        self.fc2 = nn.Linear(hidden, num_classes)

    def forward(self, x):
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.drop(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Part C — full CNN model
#
# We will stack two blocks:
#
# - Block1: 3 → 32 channels + pooling
# - Block2: 32 → 64 channels + pooling
#
# Let’s compute the spatial shapes:
# - Input: 3×32×32
# - After Block1 pooling: 32×16×16
# - After Block2 pooling: 64×8×8
# - Flatten features: 64 * 8 * 8
#
# We’ll use this value to build the classifier head.

# %%
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.block1 = ConvBlock(3, 32, kernel_size=3, padding=1, use_pool=True)
        self.block2 = ConvBlock(32, 64, kernel_size=3, padding=1, use_pool=True)

        # TODO: compute the number of features after conv blocks
        # Hint: for CIFAR-10 (32x32), after 2 pools you have 8x8 spatial size.
        in_features = 64 * 8 * 8

        self.head = ClassifierHead(in_features=in_features, num_classes=num_classes, hidden=128, dropout=0.2)

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.head(x)
        return x

model = SimpleCNN(num_classes=10)

# TODO: move model to device (GPU/CPU)
model = model.to(device)

print(model)
# Out:
# SimpleCNN(
#   (block1): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block2): ConvBlock(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (head): ClassifierHead(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (fc1): Linear(in_features=4096, out_features=128, bias=True)
#     (relu): ReLU(inplace=True)
#     (drop): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### Sanity check: forward pass shapes
#
# We’ll run a forward pass on one batch.

# %%
model.eval()
x, y = next(iter(train_loader))

# TODO: move x to device
x = x.to(device)

with torch.no_grad():
    logits = model(x)

print("Input batch:", x.shape)
print("Logits:", logits.shape)  # expected: [B, 10]
# Out:
# Input batch: torch.Size([128, 3, 32, 32])
# Logits: torch.Size([128, 10])

# %% [markdown]
# ## 6) Loss and optimizer
#
# For multi-class classification, we use:
# - `CrossEntropyLoss` (expects raw logits)
# - Optimizer: Adam (good default)

# %%
# TODO: define loss function
criterion = nn.CrossEntropyLoss()

# TODO: define optimizer (Adam) with learning rate e.g. 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# ## 7) Training utilities
#
# We will implement:
# - accuracy computation
# - one training epoch
# - evaluation on test set
#
# Common GPU :
# - model on GPU but data still on CPU (or the opposite) → device mismatch error.

# %%
def accuracy_from_logits(logits, labels):
    """Compute accuracy from model outputs and integer labels."""
    preds = logits.argmax(dim=1)
    return (preds == labels).float().mean().item()

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    total_loss = 0.0
    total_acc = 0.0
    n_batches = 0

    for images, labels in loader:
        # TODO: move images and labels to device
        images = images.to(device)
        labels = labels.to(device)

        # TODO: zero gradients
        optimizer.zero_grad()

        # TODO: forward pass
        logits = model(images)

        # TODO: compute loss
        loss = criterion(logits, labels)

        # TODO: backward pass
        loss.backward()

        # TODO: optimizer step
        optimizer.step()

        total_loss += loss.item()
        total_acc += accuracy_from_logits(logits, labels)
        n_batches += 1

    return total_loss / n_batches, total_acc / n_batches

# %%
@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    total_acc = 0.0
    n_batches = 0

    for images, labels in loader:
        # TODO: move images and labels to device
        images = images.to(device)
        labels = labels.to(device)

        # TODO: forward pass
        logits = model(images)

        # TODO: compute loss
        loss = criterion(logits, labels)

        total_loss += loss.item()
        total_acc += accuracy_from_logits(logits, labels)
        n_batches += 1

    return total_loss / n_batches, total_acc / n_batches

# %% [markdown]
# ## 8) Train the CNN
#
# We’ll train for a few epochs (fast on GPU).
#
# **Tip:** If training is slow, reduce epochs or batch size.

# %%
import time

# TODO: choose number of epochs (start with 3 to 5)
epochs = 10

history = {
    "train_loss": [], "train_acc": [],
    "test_loss": [], "test_acc": []
}

for epoch in range(1, epochs + 1):
    start = time.time()

    train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)
    test_loss, test_acc = evaluate(model, test_loader, criterion, device)

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)
    history["test_loss"].append(test_loss)
    history["test_acc"].append(test_acc)

    elapsed = time.time() - start
    print(f"Epoch {epoch:02d} | "
          f"train loss={train_loss:.4f}, train acc={train_acc:.4f} | "
          f"test loss={test_loss:.4f}, test acc={test_acc:.4f} | "
          f"time={elapsed:.1f}s")
# Out:
# Epoch 01 | train loss=1.3664, train acc=0.5044 | test loss=1.0655, test acc=0.6138 | time=14.5s
# Epoch 02 | train loss=1.0316, train acc=0.6340 | test loss=0.9734, test acc=0.6608 | time=14.5s
# Epoch 03 | train loss=0.9213, train acc=0.6764 | test loss=0.9000, test acc=0.6820 | time=14.8s
# Epoch 04 | train loss=0.8469, train acc=0.7010 | test loss=0.8760, test acc=0.6939 | time=14.1s
# Epoch 05 | train loss=0.7880, train acc=0.7224 | test loss=0.8823, test acc=0.6957 | time=14.1s
# Epoch 06 | train loss=0.7338, train acc=0.7405 | test loss=0.7884, test acc=0.7235 | time=14.1s
# Epoch 07 | train loss=0.6843, train acc=0.7580 | test loss=0.7657, test acc=0.7348 | time=14.3s
# Epoch 08 | train loss=0.6479, train acc=0.7698 | test loss=0.7755, test acc=0.7300 | time=14.0s
# Epoch 09 | train loss=0.6000, train acc=0.7868 | test loss=0.7622, test acc=0.7328 | time=14.1s
# Epoch 10 | train loss=0.5675, train acc=0.7983 | test loss=0.7840, test acc=0.7371 | time=14.2s

# %% [markdown]
# ## 9) Plot training curves

# %%
plt.figure(figsize=(6,4))
plt.plot(history["train_loss"], label="train loss")
plt.plot(history["test_loss"], label="test loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

plt.figure(figsize=(6,4))
plt.plot(history["train_acc"], label="train acc")
plt.plot(history["test_acc"], label="test acc")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## 10) Inspect predictions
#
# We’ll display a few test images and show:
# - predicted label
# - true label

# %%
@torch.no_grad()
def show_predictions(model, dataset, classes, device, n=12, seed=123):
    model.eval()
    rng = np.random.default_rng(seed)
    idxs = rng.choice(len(dataset), size=n, replace=False)

    fig, axes = plt.subplots(3, 4, figsize=(10, 7))
    axes = axes.flatten()

    for ax, idx in zip(axes, idxs):
        x, y = dataset[idx]
        x_vis = unnormalize(x).clamp(0, 1)

        # TODO: add batch dimension and move to device
        xb = x.unsqueeze(0).to(device)

        logits = model(xb)
        pred = logits.argmax(dim=1).item()

        ax.imshow(x_vis.permute(1, 2, 0))
        ax.set_title(f"pred: {classes[pred]}\ntrue: {classes[y]}", fontsize=9)
        ax.axis("off")

    plt.tight_layout()
    plt.show()

show_predictions(model, test_dataset, classes, device, n=12, seed=7)

# %% [markdown]
# ## 11) Bonus
#
# 1. Add a **third ConvBlock** (64 → 128) and update `in_features` accordingly.
# 2. Replace MaxPool with **stride=2 convolution** and compare.
# 3. Try **SGD** instead of Adam (add momentum=0.9).
# 4. Add simple data augmentation to the training transforms:
#    - RandomCrop(32, padding=4)
#    - RandomHorizontalFlip()

# %% [markdown]
# ### Visualizing CNN Stages on One Example Image, a  cat.

# %%
model.eval()

img, label = test_dataset[0]

img_vis = unnormalize(img).clamp(0, 1)

x = img.unsqueeze(0).to(device)

with torch.no_grad():
    conv_out = model.block1.conv(x)          # Apply ONLY the convolution layer from block1
    bn_out   = model.block1.bn(conv_out)    # After BatchNorm
    relu_out = model.block1.relu(bn_out)    # After ReLU
    pool_out = model.block1.pool(relu_out)  # After Pool


# Move everything back to CPU for plotting
conv_out = conv_out.cpu()
bn_out   = bn_out.cpu()
relu_out = relu_out.cpu()
pool_out = pool_out.cpu()


def plot_feature_maps(tensor, title, max_maps=6):
    """
    tensor shape: [1, C, H, W]
    """
    feature_maps = tensor[0]  # remove batch dimension
    n_maps = min(feature_maps.shape[0], max_maps)

    fig, axes = plt.subplots(1, n_maps, figsize=(15, 3))
    fig.suptitle(title)

    for i in range(n_maps):
        axes[i].imshow(feature_maps[i], cmap="viridis")
        axes[i].axis("off")

    plt.show()

# ============================================================
# Plot 

# Original Image
plt.figure(figsize=(3,3))
plt.imshow(img_vis.permute(1,2,0))
plt.title(f"Original Image ({classes[label]})")
plt.axis("off")
plt.show()

# After Convolution (linear output)
plot_feature_maps(conv_out, "After Convolution (Linear Output)")

# After BatchNorm
plot_feature_maps(bn_out, "After BatchNorm")

# After ReLU
plot_feature_maps(relu_out, "After ReLU")

# After Pooling
plot_feature_maps(pool_out, "After Max Pooling")

# %% [markdown]
# # CNN avec 3 blocs (stride=2 et dropout)

# %%
batchsize2 = 512

class SimpleCNN2(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.block1 = ConvBlock(3, 32, kernel_size=3, padding=1,use_pool=False, stride=2)
        self.block2 = ConvBlock(32, 64, kernel_size=3, padding=1, use_pool=False, stride=2)
        self.block3 = ConvBlock(64, 128, kernel_size=3, padding=1, use_pool=False, stride=2)
        self.dropout = nn.Dropout(0.2)

        # TODO: compute the number of features after conv blocks
        # for CIFAR-10 (32x32), after 3 pools you have 4x4 spatial size !
        in_features = 128 * 4 * 4

        self.head = ClassifierHead(in_features=in_features, num_classes=num_classes, hidden=128, dropout=0.2)

    def forward(self, x):
        x = self.block1(x)
        x = self.dropout(x)
        x = self.block2(x)
        x = self.dropout(x)
        x = self.block3(x)
        x = self.head(x)
        return x

model2 = SimpleCNN2(num_classes=10)

# TODO: move model to device (GPU/CPU)
model2 = model2.to(device)

print(model2)
# Out:
# SimpleCNN2(
#   (block1): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (pool): Identity()
#   )
#   (block2): ConvBlock(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (pool): Identity()
#   )
#   (block3): ConvBlock(
#     (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (pool): Identity()
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (head): ClassifierHead(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (fc1): Linear(in_features=2048, out_features=128, bias=True)
#     (relu): ReLU(inplace=True)
#     (drop): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %%
nb_epochs = 100
optimizer = torch.optim.SGD(model2.parameters(), lr=1e-2, momentum=0.9)

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(CIFAR10_MEAN, CIFAR10_STD),
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(CIFAR10_MEAN, CIFAR10_STD),
])

train_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=True,
    download=True,
    transform=train_transform,
)

test_dataset = torchvision.datasets.CIFAR10(
    root="./data",
    train=False,
    download=True,
    transform=test_transform,
)

train_loader = DataLoader(train_dataset, batch_size=batchsize2, shuffle=True, num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_dataset,  batch_size=batchsize2, shuffle=False, num_workers=2, pin_memory=True)

history2 = {
    "train_loss": [], "train_acc": [],
    "test_loss": [], "test_acc": []
}

for epoch in range(1, nb_epochs + 1):
    start = time.time()

    train_loss, train_acc = train_one_epoch(model2, train_loader, criterion, optimizer, device)
    test_loss, test_acc = evaluate(model2, test_loader, criterion, device)

    history2["train_loss"].append(train_loss)
    history2["train_acc"].append(train_acc)
    history2["test_loss"].append(test_loss)
    history2["test_acc"].append(test_acc)

    elapsed = time.time() - start
    print(f"Epoch {epoch:02d} | "
          f"train loss={train_loss:.4f}, train acc={train_acc:.4f} | "
          f"test loss={test_loss:.4f}, test acc={test_acc:.4f} | "
          f"time={elapsed:.1f}s")
# Out:
# Epoch 01 | train loss=2.0114, train acc=0.2608 | test loss=1.6876, test acc=0.3827 | time=18.3s
# Epoch 02 | train loss=1.6563, train acc=0.3920 | test loss=1.4681, test acc=0.4631 | time=19.1s
# Epoch 03 | train loss=1.5271, train acc=0.4388 | test loss=1.4067, test acc=0.4895 | time=18.0s
# Epoch 04 | train loss=1.4554, train acc=0.4650 | test loss=1.3502, test acc=0.5057 | time=19.0s
# Epoch 05 | train loss=1.4026, train acc=0.4875 | test loss=1.2681, test acc=0.5359 | time=18.4s
# Epoch 06 | train loss=1.3564, train acc=0.5068 | test loss=1.2442, test acc=0.5527 | time=18.1s
# Epoch 07 | train loss=1.3140, train acc=0.5254 | test loss=1.1831, test acc=0.5723 | time=19.0s
# Epoch 08 | train loss=1.2687, train acc=0.5436 | test loss=1.1163, test acc=0.5973 | time=17.9s
# Epoch 09 | train loss=1.2293, train acc=0.5548 | test loss=1.0859, test acc=0.6155 | time=19.2s
# Epoch 10 | train loss=1.1958, train acc=0.5690 | test loss=1.0752, test acc=0.6197 | time=18.2s
# Epoch 11 | train loss=1.1654, train acc=0.5821 | test loss=1.0478, test acc=0.6291 | time=19.3s
# Epoch 12 | train loss=1.1395, train acc=0.5904 | test loss=0.9938, test acc=0.6468 | time=18.1s
# Epoch 13 | train loss=1.1138, train acc=0.6004 | test loss=0.9762, test acc=0.6557 | time=18.6s
# Epoch 14 | train loss=1.0955, train acc=0.6043 | test loss=0.9652, test acc=0.6600 | time=19.0s
# Epoch 15 | train loss=1.0732, train acc=0.6152 | test loss=0.9503, test acc=0.6633 | time=18.0s
# Epoch 16 | train loss=1.0526, train acc=0.6232 | test loss=0.9213, test acc=0.6719 | time=18.8s
# Epoch 17 | train loss=1.0378, train acc=0.6325 | test loss=0.9121, test acc=0.6793 | time=17.8s
# Epoch 18 | train loss=1.0188, train acc=0.6328 | test loss=0.8633, test acc=0.6970 | time=18.5s
# Epoch 19 | train loss=1.0121, train acc=0.6382 | test loss=0.8730, test acc=0.6916 | time=18.3s
# Epoch 20 | train loss=0.9992, train acc=0.6401 | test loss=0.8845, test acc=0.6892 | time=17.8s
# Epoch 21 | train loss=0.9810, train acc=0.6496 | test loss=0.8523, test acc=0.6984 | time=19.2s
# Epoch 22 | train loss=0.9704, train acc=0.6549 | test loss=0.8534, test acc=0.7010 | time=17.9s
# Epoch 23 | train loss=0.9597, train acc=0.6583 | test loss=0.8341, test acc=0.7074 | time=19.0s
# Epoch 24 | train loss=0.9489, train acc=0.6630 | test loss=0.8065, test acc=0.7171 | time=18.1s
# Epoch 25 | train loss=0.9392, train acc=0.6652 | test loss=0.8160, test acc=0.7111 | time=18.3s
# Epoch 26 | train loss=0.9222, train acc=0.6716 | test loss=0.7910, test acc=0.7215 | time=18.5s
# Epoch 27 | train loss=0.9186, train acc=0.6722 | test loss=0.7930, test acc=0.7229 | time=18.0s
# Epoch 28 | train loss=0.9073, train acc=0.6778 | test loss=0.7725, test acc=0.7260 | time=18.9s
# Epoch 29 | train loss=0.9011, train acc=0.6806 | test loss=0.7733, test acc=0.7252 | time=17.9s
# Epoch 30 | train loss=0.8897, train acc=0.6860 | test loss=0.7495, test acc=0.7371 | time=18.9s
# Epoch 31 | train loss=0.8763, train acc=0.6874 | test loss=0.7380, test acc=0.7399 | time=17.8s
# Epoch 32 | train loss=0.8674, train acc=0.6919 | test loss=0.8059, test acc=0.7170 | time=18.0s
# Epoch 33 | train loss=0.8640, train acc=0.6914 | test loss=0.7583, test acc=0.7346 | time=19.1s
# Epoch 34 | train loss=0.8592, train acc=0.6950 | test loss=0.7480, test acc=0.7372 | time=18.0s
# Epoch 35 | train loss=0.8483, train acc=0.6985 | test loss=0.7343, test acc=0.7412 | time=18.7s
# Epoch 36 | train loss=0.8475, train acc=0.7004 | test loss=0.7460, test acc=0.7399 | time=18.2s
# Epoch 37 | train loss=0.8399, train acc=0.7025 | test loss=0.7084, test acc=0.7507 | time=18.9s
# Epoch 38 | train loss=0.8265, train acc=0.7077 | test loss=0.7186, test acc=0.7473 | time=18.6s
# Epoch 39 | train loss=0.8196, train acc=0.7096 | test loss=0.7025, test acc=0.7537 | time=18.4s
# Epoch 40 | train loss=0.8267, train acc=0.7084 | test loss=0.7017, test acc=0.7503 | time=19.4s
# Epoch 41 | train loss=0.8099, train acc=0.7131 | test loss=0.7095, test acc=0.7508 | time=18.1s
# Epoch 42 | train loss=0.8058, train acc=0.7141 | test loss=0.6863, test acc=0.7576 | time=19.5s
# Epoch 43 | train loss=0.7973, train acc=0.7182 | test loss=0.6898, test acc=0.7592 | time=18.4s
# Epoch 44 | train loss=0.7942, train acc=0.7196 | test loss=0.7104, test acc=0.7519 | time=19.5s
# Epoch 45 | train loss=0.7891, train acc=0.7209 | test loss=0.6880, test acc=0.7584 | time=18.4s
# Epoch 46 | train loss=0.7851, train acc=0.7229 | test loss=0.6829, test acc=0.7607 | time=19.3s
# Epoch 47 | train loss=0.7749, train acc=0.7254 | test loss=0.6704, test acc=0.7643 | time=18.5s
# Epoch 48 | train loss=0.7735, train acc=0.7281 | test loss=0.6930, test acc=0.7587 | time=18.9s
# Epoch 49 | train loss=0.7669, train acc=0.7305 | test loss=0.6721, test acc=0.7628 | time=18.9s
# Epoch 50 | train loss=0.7719, train acc=0.7272 | test loss=0.6625, test acc=0.7628 | time=18.6s
# Epoch 51 | train loss=0.7622, train acc=0.7314 | test loss=0.6614, test acc=0.7681 | time=19.1s
# Epoch 52 | train loss=0.7553, train acc=0.7322 | test loss=0.6625, test acc=0.7644 | time=18.3s
# Epoch 53 | train loss=0.7493, train acc=0.7371 | test loss=0.6637, test acc=0.7646 | time=19.5s
# Epoch 54 | train loss=0.7518, train acc=0.7336 | test loss=0.6573, test acc=0.7645 | time=18.3s
# Epoch 55 | train loss=0.7403, train acc=0.7383 | test loss=0.6593, test acc=0.7683 | time=19.4s
# Epoch 56 | train loss=0.7409, train acc=0.7405 | test loss=0.6526, test acc=0.7713 | time=18.4s
# Epoch 57 | train loss=0.7331, train acc=0.7397 | test loss=0.6453, test acc=0.7698 | time=19.3s
# Epoch 58 | train loss=0.7352, train acc=0.7396 | test loss=0.6459, test acc=0.7718 | time=18.2s
# Epoch 59 | train loss=0.7325, train acc=0.7409 | test loss=0.6530, test acc=0.7717 | time=18.3s
# Epoch 60 | train loss=0.7284, train acc=0.7429 | test loss=0.6480, test acc=0.7741 | time=18.9s
# Epoch 61 | train loss=0.7228, train acc=0.7443 | test loss=0.6332, test acc=0.7789 | time=18.2s
# Epoch 62 | train loss=0.7221, train acc=0.7456 | test loss=0.6364, test acc=0.7786 | time=19.4s
# Epoch 63 | train loss=0.7243, train acc=0.7441 | test loss=0.6178, test acc=0.7830 | time=18.4s
# Epoch 64 | train loss=0.7116, train acc=0.7479 | test loss=0.6362, test acc=0.7776 | time=19.4s
# Epoch 65 | train loss=0.7105, train acc=0.7476 | test loss=0.6267, test acc=0.7802 | time=18.2s
# Epoch 66 | train loss=0.7106, train acc=0.7500 | test loss=0.6329, test acc=0.7823 | time=19.5s
# Epoch 67 | train loss=0.7056, train acc=0.7502 | test loss=0.6209, test acc=0.7852 | time=18.2s
# Epoch 68 | train loss=0.7033, train acc=0.7528 | test loss=0.6131, test acc=0.7833 | time=18.3s
# Epoch 69 | train loss=0.7022, train acc=0.7513 | test loss=0.6158, test acc=0.7863 | time=19.5s
# Epoch 70 | train loss=0.6968, train acc=0.7537 | test loss=0.6306, test acc=0.7825 | time=18.3s
# Epoch 71 | train loss=0.7009, train acc=0.7534 | test loss=0.6116, test acc=0.7845 | time=19.4s
# Epoch 72 | train loss=0.6962, train acc=0.7543 | test loss=0.6197, test acc=0.7812 | time=18.4s
# Epoch 73 | train loss=0.6909, train acc=0.7559 | test loss=0.5999, test acc=0.7913 | time=19.5s
# Epoch 74 | train loss=0.6912, train acc=0.7551 | test loss=0.6066, test acc=0.7877 | time=18.4s
# Epoch 75 | train loss=0.6841, train acc=0.7577 | test loss=0.6031, test acc=0.7896 | time=19.5s
# Epoch 76 | train loss=0.6851, train acc=0.7580 | test loss=0.5920, test acc=0.7923 | time=18.4s
# Epoch 77 | train loss=0.6762, train acc=0.7615 | test loss=0.6058, test acc=0.7884 | time=19.0s
# Epoch 78 | train loss=0.6758, train acc=0.7615 | test loss=0.6136, test acc=0.7864 | time=18.4s
# Epoch 79 | train loss=0.6723, train acc=0.7622 | test loss=0.6119, test acc=0.7904 | time=17.8s
# Epoch 80 | train loss=0.6756, train acc=0.7621 | test loss=0.5910, test acc=0.7946 | time=18.6s
# Epoch 81 | train loss=0.6675, train acc=0.7642 | test loss=0.5927, test acc=0.7944 | time=17.8s
# Epoch 82 | train loss=0.6708, train acc=0.7641 | test loss=0.5825, test acc=0.7950 | time=18.7s
# Epoch 83 | train loss=0.6694, train acc=0.7643 | test loss=0.5827, test acc=0.7950 | time=18.2s
# Epoch 84 | train loss=0.6632, train acc=0.7629 | test loss=0.5914, test acc=0.7935 | time=17.9s
# Epoch 85 | train loss=0.6599, train acc=0.7700 | test loss=0.5923, test acc=0.7948 | time=18.9s
# Epoch 86 | train loss=0.6621, train acc=0.7660 | test loss=0.5947, test acc=0.7919 | time=17.9s
# Epoch 87 | train loss=0.6480, train acc=0.7708 | test loss=0.5950, test acc=0.7915 | time=18.7s
# Epoch 88 | train loss=0.6631, train acc=0.7674 | test loss=0.5790, test acc=0.7963 | time=18.2s
# Epoch 89 | train loss=0.6555, train acc=0.7697 | test loss=0.5759, test acc=0.7992 | time=17.8s
# Epoch 90 | train loss=0.6526, train acc=0.7681 | test loss=0.5884, test acc=0.7948 | time=18.8s
# Epoch 91 | train loss=0.6543, train acc=0.7686 | test loss=0.5696, test acc=0.8001 | time=18.0s
# Epoch 92 | train loss=0.6492, train acc=0.7714 | test loss=0.5812, test acc=0.7977 | time=19.2s
# Epoch 93 | train loss=0.6508, train acc=0.7703 | test loss=0.5705, test acc=0.8027 | time=18.1s
# Epoch 94 | train loss=0.6449, train acc=0.7741 | test loss=0.5806, test acc=0.7994 | time=18.2s
# Epoch 95 | train loss=0.6399, train acc=0.7732 | test loss=0.5740, test acc=0.8007 | time=18.8s
# Epoch 96 | train loss=0.6466, train acc=0.7711 | test loss=0.5763, test acc=0.7971 | time=18.1s
# Epoch 97 | train loss=0.6380, train acc=0.7745 | test loss=0.5748, test acc=0.8013 | time=19.0s
# Epoch 98 | train loss=0.6383, train acc=0.7764 | test loss=0.5880, test acc=0.7979 | time=18.1s
# Epoch 99 | train loss=0.6411, train acc=0.7730 | test loss=0.5732, test acc=0.8010 | time=19.0s
# Epoch 100 | train loss=0.6338, train acc=0.7756 | test loss=0.5746, test acc=0.8036 | time=18.0s

# %% [markdown]
# L'apprentissage est beaucoup plus long à cause du dropout mais aussi beaucoup plus stable, beaucoup moins d'overfitting grâce à la régularisation de l'augmentation et du dropout.
#
# Les performances sont meilleures avec une test accuracy atteignant 80% sans overfitting. On pourrait encore augmenter les epochs et atteindre davantage.

# %%
plt.figure(figsize=(6,4))
plt.plot(history2["train_loss"], label="train loss")
plt.plot(history2["test_loss"], label="test loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()

plt.figure(figsize=(6,4))
plt.plot(history2["train_acc"], label="train acc")
plt.plot(history2["test_acc"], label="test acc")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend()
plt.show()
